# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreeja-hub-code/Ai-Powered-Regulatory-Compliance-Infosys/blob/main/text_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
generator = pipeline('text-generation', model='gpt2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt = "once upon a time, a little boy"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time, a little boy, who had been in the church, had come to hear the story of the children who had been killed by the Prophet and his companions, and to discover the truth as to the origin of the Prophet's words.
#
# After reading the narrative, the man who had been in the church was asked to go to the Prophet's house and tell the story.
#
# ...

# %%
prompt = "once upon a time, a little girl"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time, a little girl who, in her dreams, has no hope in the world.
#
# "I can't find a single person who will do that," she says. "If I just stay, and I'm lucky enough to have some luck, I'm not going to be able to do that."
#
# When the world is too hot for her, she says, she'll go to work. When the world is too cold, she'll choose to live with her father. When she has been to someplace where the world doesn't seem to get warm, she'll stay home and work, and when she has been to a place where she can have a life and a family, she'll stay home and work.
#
# ...

# %%
prompt = "explain AI"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# explain AI to work. AI can't be played for fun and entertainment. I've never had a problem with it since I started playing it. I hope you guys enjoy it!
#
# I'm also not sure of my understanding of the concept of a "programming" or "programming algorithm". I'm just curious about it and you've made an excellent point. How exactly does it work? And how much does it cost?
#
# I'm not sure if the cost is actually $10 or $20 per piece. It's just that it would take me about 8 hours to develop the program.
#
# Do you have any ideas on how to use the program for fun or for profit?
#
# I have some ideas to work with but at this point, I'm still wondering.
#
# ...
